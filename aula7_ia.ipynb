# %% [markdown]
# <a href="https://colab.research.google.com/github/aannddrree/disciplinaIA/blob/main/aula7_ia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tipos de aprendizado:**
#
# *   Supervisionado
# *   Não Supervisionado
# *   Por reforço

# %%
# !pip install scikit-learn matplotlib
print('Ambiente OK')
# Out:
# ...
# Ambiente OK

# %% [markdown]
# Aprendizado Supervionado
#
# No aprendizado supervisionado, a máquina aprende com exemplos que já tem resposta.
#
# Ex.
#
# Horas de estudo -> Nota
#
# vamos ensinar o computador a prever uma nota com base nas horas que o aluno estuda.

# %%
# vamos importar algumas bibliotecas que vamos utilizar
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

#Dados para o treino
# X=> Horas de estudo
X = np.array([[1],[2],[3],[4],[5]])

# y => Notas
y = np.array([2,4,6,8,10])

# Criar o modelo
modelo = LinearRegression()

# Treinamento
modelo.fit(X,y)

#Fazer um previsão para 6 horas de estudo
horas_novas = np.array([[6]])
nota_prevista = modelo.predict(horas_novas)

print(f"Para 6 horas, a nota é: {nota_prevista[0]:.2f}")
# Out:
# Para 6 horas, a nota é: 12.00

# %%
plt.figure(figsize=(8,5))
plt.scatter(X,y,color='blue',label='Dados de Treino')
plt.plot(X,modelo.predict(X),color='red',label='Linha aprendida pelo modelo')
plt.xlabel("Horas de estudo")
plt.ylabel("Nota")
plt.title("Aprendizado Supervisionado")
plt.legend()
plt.grid(True)
plt.show()
